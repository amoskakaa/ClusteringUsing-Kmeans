# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data.head(10)
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729
# 5  24.169930  32.024780
# 6  21.665780   4.892855
# 7   4.693684  12.342170
# 8  19.211910  -1.121366
# 9   4.230391  -4.441536

# %% [markdown]
# Question 1

# %%
import matplotlib.pyplot as plt

# %%
X = data['V1'].values
Y = data['V2'].values
plt.scatter(X, Y, color='orange',marker='+')
plt.xlabel('V1')
plt.ylabel('V2')
plt.title('V2 AGAINST V1')
# Out:
# Text(0.5, 1.0, 'V2 AGAINST V1')

# %% [markdown]
# From the scatter plot, seems the data is grouped in three clusters, therefore the appropriate
# value of k would be 3.

# %% [markdown]
# Question 2

# %%
from sklearn.cluster import KMeans

# %%
#Using a k of 1
Kmean = KMeans(n_clusters=3)

# %%
kmean.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#Coordinates of centroids
print(kmean.cluster_centers_)
# Out:
# [[ 40.68362784  59.71589274]
#  [  9.4780459   10.686052  ]
#  [ 69.92418447 -10.11964119]]

# %%
#Plotting the centroids
plt.scatter(X, Y, c='orange',marker='+')
plt.scatter(40.68362784,59.71589274, s=60, c='b', marker='*')
plt.scatter(69.92418447,-10.11964119, s=60, c='g', marker='*')
plt.scatter(9.4780459 ,10.686052, s=60, c='r', marker='*')
